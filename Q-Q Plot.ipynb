# %% [markdown]
# # Q-Q Plot

# %%
#Q-Q plot
import numpy as np 
import pylab 
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
# N(2,1)
normal = np.random.normal(loc = 2, scale = 1, size=10000)
per_x = []

# N(0,1)
std_normal = np.random.normal(loc = 0, scale = 1, size=1000)
per_y = []

# 0 to 100th percentiles of std-normal
for i in range(1,101):
    per_x.append(np.percentile(normal,i))

per_x = np.array(per_x)

# 0 to 100th percentiles of std-normal
for i in range(1,101):
    per_y.append(np.percentile(std_normal,i))

per_y = np.array(per_y)

# %%
plt.scatter(per_x, per_y, c ="blue")
plt.show()

# %%
# generate 100 sanples from N(20,5)
measurements = np.random.uniform(low = -1, high = 1, size=10000) 

stats.probplot(measurements, dist="norm", plot=pylab)
pylab.show()

# %%
# generate 100 sanples from N(20,5)
measurements = np.random.normal(loc = 0, scale = 1, size=10000)

stats.probplot(measurements, dist="norm", plot=pylab)
pylab.show()
